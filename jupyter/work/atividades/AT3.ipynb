# %%
from matrix import transpor_matriz, multiplicar_matriz
A = [[1, 2], [3, 4], [5, 6]]

print("Transposição")

print(f"""\nEntrada:
python
A = {A}""")

print(f"""\nSaida:
python
{transpor_matriz(A)}""")

A = [[1, 2], [3, 4]]
B = [[5, 6], [7, 8]]

print("\nMultiplicaçao")

print(f"""\nEntrada:
python
A = {A}
B = {B} """)

print(f"""\nSaida:
python
{multiplicar_matriz(A, B)}""")
# Out:
# Transposição
#
# Entrada:
# python
# A = [[1, 2], [3, 4], [5, 6]]
#
# Saida:
# python
# [[1, 3, 5], [2, 4, 6]]
#
# Multiplicaçao
#
# Entrada:
# python
# A = [[1, 2], [3, 4]]
# B = [[5, 6], [7, 8]]
#
# Saida:
# python
# [[19, 22], [43, 50]]
